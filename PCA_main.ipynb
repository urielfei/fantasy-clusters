# %%
import pandas as pd
import numpy as np
from preprocessing.config import settings
from data_transformations import nbaData
from modelling import k_means, Kmeans_results,pca
from plot import biplot,choose_K_means,choose_K_means_sil,spectral_Kmeans, Kmeans_plot
from sklearn.preprocessing import StandardScaler
from nba_api.stats.endpoints import leaguedashplayerstats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
years = ['2017-18','2018-19','2019-20','2020-21','2021-22']
print('Biplots per year')

for year in years:
    raw = leaguedashplayerstats.LeagueDashPlayerStats(season=year).get_data_frames()[0]
    nba_data_obj = nbaData(raw)
    df = nba_data_obj.get_data(scaled=True)
    p = pca(df)
    pca_coef = p[0]
    pca_scores = p[1]
    biplot(df,pca_coef,pca_scores,title=(year+' season'))
# Out:
# Biplots per year
